# %% [markdown]
# Import packages:

# %%
import csv
import pandas as pd

# %% [markdown]
# Defining function to update csv file:

# %%
def update_csv_file(csv_file_path, *database_lists):
    """
    Combine multiple lists of databases, remove duplicates based on URL, and write the results to a CSV file.

    Args:
        csv_file_path (str): Path to the CSV file to be created/updated.
        *database_lists (list of dicts): Variable number of lists containing database information.
    """
    # Combine all provided database lists into one, using the URL as a unique identifier to remove duplicates
    combined_databases = {db['URL']: db for database_list in database_lists for db in database_list}.values()
    
    # Write the combined list to the CSV file
    with open(csv_file_path, mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=["Name", "URL", "Category", "Description", "Misc"])
        writer.writeheader()
        for db in combined_databases:
            writer.writerow(db)

# %% [markdown]
# Add new databases below. Give new name to each new database. Use template below to add new row in the database.

# %% [markdown]
# {
#     "Name": "Name Here",
#     "URL": "Link Here",
#     "Category": "Assigned Category",
#     "Description": "Describe in Few Words"
#     }

# %%
dbnews = [
    {
        "Name": "The Kathmandu Post",
        "URL": "https://kathmandupost.com/",
        "Category": "General News",
        "Description": "English-language daily newspaper with comprehensive coverage of Nepali news."
    },
    {
        "Name": "Kantipur",
        "URL": "https://ekantipur.com/",
        "Category": "General News",
        "Description": "Nepali-language daily newspaper, known for its wide reach and in-depth reporting."
    },
    {
        "Name": "Setopati",
        "URL": "https://setopati.com/",
        "Category": "General News, Online",
        "Description": "Leading online news portal offering news in both Nepali and English."
    },
    {
        "Name": "Himal Khabarpatrika",
        "URL": "https://www.himalkhabar.com/",
        "Category": "Magazine, Current Affairs",
        "Description": "Popular bi-weekly magazine focusing on current affairs, politics, and social issues."
    },
    {
        "Name": "Onlinekhabar",
        "URL": "https://www.onlinekhabar.com/",
        "Category": "General News, Online",
        "Description": "One of Nepal’s most visited online news portals with news in Nepali."
    },
    {
        "Name": "Nagarik News",
        "URL": "https://nagariknews.nagariknetwork.com/",
        "Category": "General News",
        "Description": "Nepali-language newspaper covering a range of national and international news."
    },
    {
        "Name": "BBC Nepali",
        "URL": "https://www.bbc.com/nepali",
        "Category": "International News, Radio",
        "Description": "BBC's Nepali-language service providing international and national news."
    },
    {
        "Name": "My Republica",
        "URL": "https://myrepublica.nagariknetwork.com/",
        "Category": "General News",
        "Description": "English-language newspaper focused on Nepali news, business, and culture."
    },
    {
        "Name": "Nepal News",
        "URL": "https://nepalnews.com/",
        "Category": "General News, Online",
        "Description": "Online news portal covering various topics including politics, sports, and entertainment."
    },
    {
        "Name": "Ratopati",
        "URL": "https://www.ratopati.com/",
        "Category": "General News, Online",
        "Description": "Popular online news portal offering news in Nepali and English."
    },
    {
        "Name": "DC Nepal",
        "URL": "https://www.dcnepal.com/",
        "Category": "General News, Online",
        "Description": "Online news portal with a focus on Nepali diaspora news and national news."
    },
    {
        "Name": "Image Khabar",
        "URL": "https://www.imagekhabar.com/",
        "Category": "General News, Online",
        "Description": "Online news portal offering multimedia news content including videos."
    },
    {
        "Name": "News24Nepal",
        "URL": "https://www.news24nepal.tv/",
        "Category": "General News, Television",
        "Description": "Television news channel with an online presence providing Nepali news."
    },
    {
        "Name": "Nepali Times",
        "URL": "https://www.nepalitimes.com/",
        "Category": "Weekly News, English",
        "Description": "Weekly English-language newspaper offering in-depth analysis on current affairs."
    },
    {
        "Name": "Ujyaalo Online",
        "URL": "https://ujyaaloonline.com/",
        "Category": "General News, Radio, Online",
        "Description": "Online news portal affiliated with Ujyaalo Radio, offering news in Nepali."
    },
    {
        "Name": "Khabarhub",
        "URL": "https://english.khabarhub.com/",
        "Category": "General News, Online",
        "Description": "Online news portal offering news in both Nepali and English."
    },
    {
        "Name": "Rising Nepal",
        "URL": "https://risingnepaldaily.com/",
        "Category": "General News, English",
        "Description": "State-run English-language daily newspaper covering national news."
    },
    {
        "Name": "Gorkhapatra",
        "URL": "https://gorkhapatraonline.com/",
        "Category": "General News, Nepali",
        "Description": "Nepal’s oldest newspaper, state-run, offering news in Nepali."
    },
    {
        "Name": "Annapurna Post",
        "URL": "https://annapurnapost.com/",
        "Category": "General News",
        "Description": "Daily Nepali-language newspaper with a wide readership."
    },
    {
        "Name": "Deshsanchar",
        "URL": "https://deshsanchar.com/",
        "Category": "General News, Online",
        "Description": "Online news portal with a focus on Nepali politics and current affairs."
    },
    {
        "Name": "Nepalipatra",
        "URL": "https://www.nepalipatra.com/",
        "Category": "General News, Diaspora",
        "Description": "Online news portal targeting the Nepali diaspora, offering news in Nepali."
    },
    {
        "Name": "Surksha Khabar",
        "URL": "https://www.surkshakhabar.com/",
        "Category": "Security News",
        "Description": "News portal focused on security and crime news in Nepal."
    },
    {
        "Name": "Khabar Nepal",
        "URL": "https://khabarnepal.com/",
        "Category": "General News, Online",
        "Description": "Online news portal covering a wide range of topics in Nepali."
    },
    {
        "Name": "Himalaya TV",
        "URL": "https://www.himalayatv.com/",
        "Category": "Television, General News",
        "Description": "Television channel with an online platform offering Nepali news."
    },
    {
        "Name": "Baahrakhari",
        "URL": "https://www.baahrakhari.com/",
        "Category": "General News, Online",
        "Description": "Online news portal providing in-depth news coverage in Nepali."
    },
    {
        "Name": "Sajha Post",
        "URL": "https://www.sajhapost.com/",
        "Category": "General News, Online",
        "Description": "Popular online news portal offering news, blogs, and opinions in Nepali."
    },
    {
        "Name": "Lokantar",
        "URL": "https://www.lokantar.com/",
        "Category": "General News, Online",
        "Description": "Online news portal providing national and international news in Nepali."
    },
    {
        "Name": "Hamrakura",
        "URL": "https://www.hamrakura.com/",
        "Category": "General News, Online",
        "Description": "Online platform delivering news updates and analysis in Nepali."
    },
    {
        "Name": "Nepali Headline",
        "URL": "https://www.nepaliheadline.com/",
        "Category": "General News, Online",
        "Description": "Online news portal offering the latest news and headlines in Nepali."
    },
    {
        "Name": "Makal Khabar",
        "URL": "https://makalkhabar.com/",
        "Category": "General News, Online",
        "Description": "Online news platform providing news and articles in Nepali."
    },
    {
        "Name": "Sourya Daily",
        "URL": "https://www.souryadaily.com/",
        "Category": "General News, Daily",
        "Description": "Daily Nepali-language newspaper providing comprehensive news coverage."
    },
    {
        "Name": "Khabar Bhitra",
        "URL": "https://www.khabarbhitra.com/",
        "Category": "General News, Online",
        "Description": "Online news portal with a focus on Nepali news and current affairs."
    },
    {
        "Name": "Prateek Daily",
        "URL": "https://www.prateekdaily.com/",
        "Category": "General News, Daily",
        "Description": "Nepali-language daily newspaper offering national and international news."
    },
    {
        "Name": "Samudrapari",
        "URL": "https://www.samudrapari.com/",
        "Category": "Diaspora News, Online",
        "Description": "Online news portal targeting Nepali communities abroad."
    },
    {
        "Name": "Nepal Samaya",
        "URL": "https://www.nepalsamaya.com/",
        "Category": "General News, Online",
        "Description": "Nepali news portal covering current events and issues."
    },
    {
        "Name": "Janata Samachar",
        "URL": "https://www.janatasamachar.com/",
        "Category": "General News, Online",
        "Description": "News portal offering updates and analysis on various topics in Nepali."
    },
    {
        "Name": "Shilapatra",
        "URL": "https://www.shilapatra.com/",
        "Category": "General News, Online",
        "Description": "Online news portal delivering news and opinion pieces in Nepali."
    },
    {
        "Name": "Nepal Press",
        "URL": "https://www.nepalpress.com/",
        "Category": "General News, Online",
        "Description": "Digital news platform providing breaking news and in-depth reports in Nepali."
    },
    {
        "Name": "Desh Sanchar",
        "URL": "https://www.deshsanchar.com/",
        "Category": "General News, Online",
        "Description": "News portal focused on providing Nepali news and features."
    },
    {
        "Name": "eAdarsha",
        "URL": "https://www.eadarsha.com/",
        "Category": "General News, Online",
        "Description": "Online news portal providing news updates primarily for the Pokhara region in Nepali."
    },
    {
        "Name": "News Kantipur",
        "URL": "https://www.newskantipur.com/",
        "Category": "General News, Online",
        "Description": "Digital news platform offering breaking news and current affairs in Nepali."
    },
    {
        "Name": "Nepal Page",
        "URL": "https://www.nepalpage.com/",
        "Category": "General News, Online",
        "Description": "Online news portal providing national and international news in Nepali."
    },
    {
        "Name": "Everest Times",
        "URL": "https://www.everest-times.com/",
        "Category": "General News, Diaspora",
        "Description": "News platform targeting the Nepali diaspora, offering news in both Nepali and English."
    },
    {
        "Name": "Madheshvani",
        "URL": "https://www.madheshvani.com/",
        "Category": "Regional News, Online",
        "Description": "Online news portal focusing on news and issues from the Madhesh region of Nepal."
    },
    {
        "Name": "Pahilopost",
        "URL": "https://pahilopost.com/",
        "Category": "General News, Online",
        "Description": "Online news platform known for its prompt updates on national events in Nepali."
    },
    {
        "Name": "Bizmandu",
        "URL": "https://www.bizmandu.com/",
        "Category": "Business News, Online",
        "Description": "Online portal providing business news and economic updates in Nepali."
    },
    {
        "Name": "eKhabar",
        "URL": "https://www.ekhabar.com/",
        "Category": "General News, Online",
        "Description": "Digital news platform offering a wide range of news topics in Nepali."
    },
    {
        "Name": "Nepali Sansar",
        "URL": "https://www.nepalisansar.com/",
        "Category": "Diaspora News, Online",
        "Description": "News portal catering to the Nepali community abroad with updates in English."
    },
    {
        "Name": "Naya Patrika",
        "URL": "https://www.nayapatrikadaily.com/",
        "Category": "General News, Daily",
        "Description": "Daily newspaper providing comprehensive coverage of news in Nepali."
    },
    {
        "Name": "Purwanchal Khabar",
        "URL": "https://www.purwanchalkhabar.com/",
        "Category": "Regional News, Online",
        "Description": "News portal focusing on the eastern region of Nepal, offering news in Nepali."
    },
    {
        "Name": "Khojtalash",
        "URL": "https://khojtalash.com/",
        "Category": "Investigative News, Online",
        "Description": "News portal dedicated to investigative journalism and in-depth reporting in Nepali."
    },
    {
        "Name": "Nayakhabar",
        "URL": "https://www.nayakhabar.com/",
        "Category": "General News, Online",
        "Description": "Online news platform offering the latest news and features in Nepali."
    },
    {
        "Name": "Nepali Aawaz",
        "URL": "https://www.nepaliaawaz.com/",
        "Category": "Diaspora News, Online",
        "Description": "News portal focused on Nepali diaspora communities with content in Nepali."
    },
    {
        "Name": "Bhaskar Daily",
        "URL": "https://www.bhaskardaily.com/",
        "Category": "General News, Online",
        "Description": "Online news portal offering news and updates in Nepali."
    },
    {
        "Name": "Headline Nepal",
        "URL": "https://www.headlinenepal.com/",
        "Category": "General News, Online",
        "Description": "Digital news portal providing national news and updates in Nepali."
    },
    {
        "Name": "Nepalaja",
        "URL": "https://www.nepalaja.com/",
        "Category": "General News, Online",
        "Description": "Online news platform delivering news on various topics in Nepali."
    },
    {
        "Name": "Swatantra Khabar",
        "URL": "https://swatantrakhabar.com/",
        "Category": "General News, Online",
        "Description": "News portal offering the latest news and opinions in Nepali."
    },
    {
        "Name": "Hello Nepal",
        "URL": "https://hellonepalnews.com/",
        "Category": "Diaspora News, Online",
        "Description": "Online news portal for the Nepali diaspora, providing news and updates in Nepali."
    },
    {
        "Name": "Nepal Sanchar",
        "URL": "https://www.nepalsanchar.com/",
        "Category": "General News, Online",
        "Description": "News portal providing national and international news in Nepali."
    },
    {
        "Name": "Janakpur Today",
        "URL": "https://www.janakpurtoday.com/",
        "Category": "Regional News, Online",
        "Description": "News portal focusing on Janakpur and the Madhesh region, offering news in Nepali."
    },
    {
        "Name": "Enewspolar",
        "URL": "https://www.enewspolar.com/",
        "Category": "General News, Online",
        "Description": "Online news portal delivering the latest updates and news in Nepali."
    },
    {
        "Name": "Himalayan Times",
        "URL": "https://thehimalayantimes.com/",
        "Category": "General News, English",
        "Description": "Leading English-language daily newspaper in Nepal, covering national and international news."
    },
    {
        "Name": "Gorkha Express",
        "URL": "https://www.gorkhaexpress.com/",
        "Category": "General News, Online",
        "Description": "Online news portal providing news and updates in Nepali."
    },
    {
        "Name": "Purbeli",
        "URL": "https://purbelinews.com/",
        "Category": "Regional News, Online",
        "Description": "News portal focused on the eastern region of Nepal, providing news in Nepali."
    },
    {
        "Name": "Sudarshan News",
        "URL": "https://www.sudarshannews.com/",
        "Category": "General News, Online",
        "Description": "Digital news portal offering a range of news topics in Nepali."
    },
    {
        "Name": "Nepal Post Daily",
        "URL": "https://www.nepalpostdaily.com/",
        "Category": "General News, Online",
        "Description": "News portal providing national and international news in Nepali."
    },
    {
        "Name": "Saptahik",
        "URL": "https://saptahik.com.np/",
        "Category": "Weekly News, Entertainment",
        "Description": "Weekly magazine focusing on entertainment and lifestyle news in Nepali."
    },
    {
        "Name": "Nepal Update",
        "URL": "https://www.nepalupdate.com/",
        "Category": "General News, Online",
        "Description": "Online platform providing the latest news updates in Nepali."
    },
    {
        "Name": "Khasokhas",
        "URL": "https://khasokhas.com/",
        "Category": "Diaspora News, Online",
        "Description": "News portal catering to the Nepali community abroad, offering news in Nepali."
    },
    {
        "Name": "Khulapatra",
        "URL": "https://khulapatra.com/",
        "Category": "General News, Online",
        "Description": "Online news portal delivering national news and current affairs in Nepali."
    },
    {
        "Name": "Nepali E-Chords",
        "URL": "https://www.nepaliechords.com/",
        "Category": "Music News, Online",
        "Description": "News portal dedicated to Nepali music, providing news and updates in Nepali."
    },
    {
        "Name": "Nepal Focus",
        "URL": "https://www.nepalfocus.com/",
        "Category": "General News, Online",
        "Description": "Online news portal offering news and analysis in Nepali."
    },
    {
        "Name": "Mero Khabar",
        "URL": "https://merokhabar.com/",
        "Category": "General News, Online",
        "Description": "News portal providing national news and updates in Nepali."
    },
    {
        "Name": "Nepalipatra",
        "URL": "https://www.nepalipatra.com/",
        "Category": "General News, Diaspora",
        "Description": "Online news portal targeting the Nepali diaspora, offering news in Nepali."
    },
    {
        "Name": "Jhapa News",
        "URL": "https://www.jhapanews.com/",
        "Category": "Regional News, Online",
        "Description": "News portal focusing on the Jhapa region, offering news in Nepali."
    },
    {
        "Name": "Nepal Pyaro",
        "URL": "https://nepalpyaro.com/",
        "Category": "General News, Online",
        "Description": "Online news portal offering the latest updates in Nepali."
    },
    {
        "Name": "Khabar Dainik",
        "URL": "https://www.khabardainik.com/",
        "Category": "General News, Online",
        "Description": "Digital news portal delivering national and international news in Nepali."
    },
    {
        "Name": "Naya Samachar",
        "URL": "https://nayasamachar.com/",
        "Category": "General News, Online",
        "Description": "News portal offering updates on current events in Nepali."
    },
    {
        "Name": "Serofero",
        "URL": "https://seroferonews.com/",
        "Category": "General News, Online",
        "Description": "Online news portal providing in-depth news coverage in Nepali."
    },
    {
        "Name": "Nepali Times",
        "URL": "https://www.nepalitimes.com/",
        "Category": "General News, English",
        "Description": "Leading English-language weekly newspaper covering national and international news."
    },
    {
        "Name": "DCnepal",
        "URL": "https://dcnepal.com/",
        "Category": "Diaspora News, Online",
        "Description": "News portal focused on the Nepali diaspora, providing news and updates in both Nepali and English."
    },
    {
        "Name": "Bhojpurkhabar",
        "URL": "https://www.bhojpurkhabar.com/",
        "Category": "Regional News, Online",
        "Description": "News portal covering news from the Bhojpur district, offering content in Nepali."
    },
    {
        "Name": "News24 Nepal",
        "URL": "https://www.news24nepal.tv/",
        "Category": "General News, Television",
        "Description": "Television news channel offering 24-hour news coverage in Nepali."
    },
    {
        "Name": "Nepali Diary",
        "URL": "https://nepalidiary.com/",
        "Category": "General News, Online",
        "Description": "Digital news platform providing national and international news in Nepali."
    },
    {
        "Name": "Lokaantar",
        "URL": "https://lokaantar.com/",
        "Category": "General News, Online",
        "Description": "Online news portal offering a variety of news topics in Nepali."
    },
    {
        "Name": "Janakpur News",
        "URL": "https://janakpurnews.com/",
        "Category": "Regional News, Online",
        "Description": "News portal focusing on news from Janakpur and surrounding areas in Nepali."
    },
    {
        "Name": "Ekantipur",
        "URL": "https://ekantipur.com/",
        "Category": "General News, Online",
        "Description": "One of the most popular online news portals in Nepal, offering news in both Nepali and English."
    },
    {
        "Name": "DCnepal Samachar",
        "URL": "https://www.dcnepal.com/",
        "Category": "Diaspora News, Online",
        "Description": "News portal for the Nepali diaspora, delivering updates in Nepali."
    },
    {
        "Name": "My Republica",
        "URL": "https://myrepublica.nagariknetwork.com/",
        "Category": "General News, English",
        "Description": "English-language daily providing news and analysis on current events."
    },
    {
        "Name": "Nepalitelegraph",
        "URL": "https://nepalitelegraph.com/",
        "Category": "Diaspora News, Online",
        "Description": "News portal serving the Nepali diaspora with news and updates in Nepali."
    },
    {
        "Name": "Online Khabar",
        "URL": "https://www.onlinekhabar.com/",
        "Category": "General News, Online",
        "Description": "Leading digital news portal offering comprehensive coverage of news in Nepali."
    },
    {
        "Name": "Rising Nepal",
        "URL": "https://therisingnepal.org.np/",
        "Category": "General News, English",
        "Description": "Government-owned English-language daily newspaper offering news and views."
    },
    {
        "Name": "Kathmandu Post",
        "URL": "https://kathmandupost.com/",
        "Category": "General News, English",
        "Description": "One of the leading English-language dailies in Nepal, covering a wide range of news."
    },
    {
        "Name": "Nepal Diary",
        "URL": "https://nepaldiary.com/",
        "Category": "General News, Online",
        "Description": "Digital platform delivering news and articles on current affairs in Nepali."
    },
    {
        "Name": "Nepali Patra",
        "URL": "https://www.nepalipatra.com/",
        "Category": "Diaspora News, Online",
        "Description": "News portal aimed at the Nepali community abroad, offering news in Nepali."
    },
    {
        "Name": "Nepalitelegraph",
        "URL": "https://nepalitelegraph.com/",
        "Category": "Diaspora News, Online",
        "Description": "News portal catering to the Nepali diaspora with updates in Nepali."
    },
    {
        "Name": "Rajdhani Daily",
        "URL": "https://rajdhanidaily.com/",
        "Category": "General News, Daily",
        "Description": "Daily newspaper providing national and international news in Nepali."
    },
    {
        "Name": "Setopati",
        "URL": "https://setopati.com/",
        "Category": "General News, Online",
        "Description": "Popular online news portal offering in-depth news and analysis in Nepali."
    },
    {
        "Name": "Nepal Samacharpatra",
        "URL": "https://nepalsamacharpatra.com/",
        "Category": "General News, Daily",
        "Description": "Nepali-language daily newspaper covering a wide range of topics."
    },
    {
        "Name": "Annapurna Post",
        "URL": "https://annapurnapost.com/",
        "Category": "General News, Daily",
        "Description": "Popular daily newspaper in Nepal providing news and analysis in Nepali."
    },
    {
        "Name": "Hamrakura",
        "URL": "https://hamrakura.com/",
        "Category": "General News, Online",
        "Description": "Online news portal offering a wide range of news topics in Nepali."
    },
    {
        "Name": "Nepal Samaya",
        "URL": "https://nepalsamaya.com/",
        "Category": "General News, Online",
        "Description": "Digital news platform providing national and international news in Nepali."
    },
    {
        "Name": "Ratopati",
        "URL": "https://ratopati.com/",
        "Category": "General News, Online",
        "Description": "One of the most popular online news portals in Nepal, offering news in Nepali."
    },
    {
        "Name": "Image Khabar",
        "URL": "https://imagekhabar.com/",
        "Category": "General News, Online",
        "Description": "Online news portal providing news coverage on various topics in Nepali."
    },
    {
        "Name": "Khabarhub",
        "URL": "https://khabarhub.com/",
        "Category": "General News, Online",
        "Description": "Digital news platform offering news and updates in Nepali and English."
    },
    {
        "Name": "Deshsanchar",
        "URL": "https://deshsanchar.com/",
        "Category": "General News, Online",
        "Description": "Online news portal providing in-depth news coverage in Nepali."
    },
    {
        "Name": "Shilapatra",
        "URL": "https://shilapatra.com/",
        "Category": "General News, Online",
        "Description": "Popular online news platform offering news and opinions in Nepali."
    },
    {
        "Name": "Thahakhabar",
        "URL": "https://thahakhabar.com/",
        "Category": "General News, Online",
        "Description": "Online news portal known for its comprehensive coverage of current affairs in Nepali."
    },
    {
        "Name": "Nagarik News",
        "URL": "https://nagariknews.nagariknetwork.com/",
        "Category": "General News, Daily",
        "Description": "Widely read daily newspaper in Nepal, offering news in Nepali."
    },
    {
        "Name": "Mysansar",
        "URL": "https://mysansar.com/",
        "Category": "General News, Blog",
        "Description": "Popular Nepali blog providing news, opinions, and analysis."
    },
    {
        "Name": "Samacharpati",
        "URL": "https://samacharpati.com/",
        "Category": "General News, Online",
        "Description": "Online news platform providing national and international news in Nepali."
    },
    {
        "Name": "Dainik Nepal",
        "URL": "https://dainiknepal.com/",
        "Category": "General News, Online",
        "Description": "Online news portal offering the latest news and updates in Nepali."
    },
    {
        "Name": "Nepal Khabar",
        "URL": "https://nepalkhabar.com/",
        "Category": "General News, Online",
        "Description": "Digital news platform providing a variety of news topics in Nepali."
    },
    {
        "Name": "Bizkhabar",
        "URL": "https://bizkhabar.com/",
        "Category": "Business News, Online",
        "Description": "Online portal dedicated to business news and economic updates in Nepali."
    },
    {
        "Name": "Suprabhat",
        "URL": "https://suprabhatonline.com/",
        "Category": "General News, Online",
        "Description": "Online news portal offering news and updates in Nepali."
    },
    {
        "Name": "Naya Patrika",
        "URL": "https://www.nayapatrikadaily.com/",
        "Category": "General News, Daily",
        "Description": "Daily newspaper providing comprehensive coverage of news in Nepali."
    },
    {
        "Name": "Pahilopost",
        "URL": "https://pahilopost.com/",
        "Category": "General News, Online",
        "Description": "Online news platform known for its prompt updates on national events in Nepali."
    },
    {
        "Name": "Abhiyan",
        "URL": "https://abhiyan.com.np/",
        "Category": "Business News, Online",
        "Description": "News portal focusing on business and economic news in Nepali."
    },
    {
        "Name": "Sourya Daily",
        "URL": "https://souryadaily.com/",
        "Category": "General News, Daily",
        "Description": "Daily newspaper offering national and international news in Nepali."
    },
    {
        "Name": "Nepal Live Today",
        "URL": "https://www.nepallivetoday.com/",
        "Category": "General News, Online",
        "Description": "Digital news platform offering news, analysis, and features in English."
    },
    {
        "Name": "Sansar News",
        "URL": "https://sansarnews.com/",
        "Category": "General News, Online",
        "Description": "Online news portal offering a wide range of news topics in Nepali."
    },
    {
        "Name": "Lokantar",
        "URL": "https://lokaantar.com/",
        "Category": "General News, Online",
        "Description": "Online news platform providing news and updates in Nepali."
    },
    {
        "Name": "Nepali Headlines",
        "URL": "https://nepaliheadlines.com/",
        "Category": "General News, Online",
        "Description": "Online news portal offering news, features, and opinions in Nepali."
    },
    {
        "Name": "Samaya Post",
        "URL": "https://samayapost.com/",
        "Category": "Business News, Online",
        "Description": "News portal dedicated to business, finance, and economic news in Nepali."
    },
    {
        "Name": "Rajdhani Daily",
        "URL": "https://rajdhanidaily.com/",
        "Category": "General News, Daily",
        "Description": "Daily newspaper offering a wide range of news coverage in Nepali."
    },
    {
        "Name": "Purwanchal Khabar",
        "URL": "https://purwanchalkhabar.com/",
        "Category": "Regional News, Online",
        "Description": "News portal focusing on the eastern region of Nepal, offering news in Nepali."
    },
    {
        "Name": "Nepal Aaja",
        "URL": "https://nepalaaja.com/",
        "Category": "General News, Online",
        "Description": "Online news portal delivering news on various topics in Nepali."
    },
    {
        "Name": "Khojtalash",
        "URL": "https://khojtalash.com/",
        "Category": "Investigative News, Online",
        "Description": "News portal dedicated to investigative journalism and in-depth reporting in Nepali."
    }
]

# %% [markdown]
# Use format below to update above . Use following prompt to search journals using ChatGPT:
#
# List paper search engine in the format below. Exclude [] in the code:
# {
#     "Name": "Name Here",
#     "URL": "URL Here",
#     "Category": " Category Here",
#     "Description": "Description of journal",
#     "Misc": "Write Misc Here"
# },

# %%
# Filepath to save the CSV
csv_file_path = "Nepali News Portals.csv"

# Call the function with any number of database lists
update_csv_file(csv_file_path, dbnews)

print(f"CSV file '{csv_file_path}' has been updated.")

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Get the dimensions of the DataFrame
num_rows, num_columns = df.shape

print(f"The CSV file has {num_rows} rows and {num_columns} columns.")
# Out:
# CSV file 'Nepali News Portals.csv' has been updated.
# The CSV file has 109 rows and 5 columns.
