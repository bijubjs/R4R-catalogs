# %%
import csv
import pandas as pd

# %%
def update_csv_file(csv_file_path, *database_lists):
    """
    Combine multiple lists of databases, remove duplicates based on URL, and write the results to a CSV file.

    Args:
        csv_file_path (str): Path to the CSV file to be created/updated.
        *database_lists (list of dicts): Variable number of lists containing database information.
    """
    # Combine all provided database lists into one, using the URL as a unique identifier to remove duplicates
    combined_databases = {db['URL']: db for database_list in database_lists for db in database_list}.values()
    
    # Write the combined list to the CSV file
    with open(csv_file_path, mode='w', newline='') as file:
        writer = csv.DictWriter(file, fieldnames=["Name", "Broad Field", "URL", "Cite Score", "Impact Factor", "Description", "Misc"])
        writer.writeheader()
        for db in combined_databases:
            writer.writerow(db)

# %% [markdown]
# Use template below to create new row in dataset.

# %%
jdb0829241600 = [
    # General Social Science
    {
        "Name": "American Journal of Sociology",
        "Broad Field": "Sociology",
        "URL": "https://www.journals.uchicago.edu/toc/ajs/current",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "A leading journal in sociology with a broad focus on sociological research."
    },
    {
        "Name": "Sociological Review",
        "Broad Field": "Sociology",
        "URL": "https://onlinelibrary.wiley.com/journal/1467954x",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Publishes high-quality research across all areas of sociology."
    },
    {
        "Name": "Social Forces",
        "Broad Field": "Sociology",
        "URL": "https://academic.oup.com/sf",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Focuses on social theory and empirical research in sociology."
    },
    {
        "Name": "Journal of Sociology and Social Welfare",
        "Broad Field": "Sociology",
        "URL": "https://www.jstor.org/journal/josociasocwelf",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Dedicated to research on social welfare and its impact on society."
    },
    {
        "Name": "Social Science Research",
        "Broad Field": "Sociology",
        "URL": "https://www.journals.elsevier.com/social-science-research",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Provides a platform for research in social science methods and theory."
    },
    # Sociology
    {
        "Name": "Annual Review of Sociology",
        "Broad Field": "Sociology",
        "URL": "https://www.annualreviews.org/journal/soc",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Reviews significant developments in sociology and related fields."
    },
    {
        "Name": "Social Problems",
        "Broad Field": "Sociology",
        "URL": "https://academic.oup.com/socpro",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Addresses contemporary social issues and problems."
    },
    {
        "Name": "Sociology of Education",
        "Broad Field": "Sociology",
        "URL": "https://journals.sagepub.com/home/soe",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Examines educational institutions and processes from a sociological perspective."
    },
    {
        "Name": "Journal of Marriage and Family",
        "Broad Field": "Sociology",
        "URL": "https://onlinelibrary.wiley.com/journal/17413737",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Focuses on research related to family and marital relationships."
    },
    {
        "Name": "Gender & Society",
        "Broad Field": "Sociology",
        "URL": "https://journals.sagepub.com/home/gas",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Explores gender and sexuality issues in social contexts."
    },
    # Political Science
    {
        "Name": "American Political Science Review",
        "Broad Field": "Political Science",
        "URL": "https://www.cambridge.org/core/journals/american-political-science-review",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Covers a broad range of political science research and theory."
    },
    {
        "Name": "Journal of Politics",
        "Broad Field": "Political Science",
        "URL": "https://academic.oup.com/jop",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Publishes research on all areas of political science."
    },
    {
        "Name": "Political Science Quarterly",
        "Broad Field": "Political Science",
        "URL": "https://www.psqonline.org/",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Features scholarly articles on political science theory and practice."
    },
    {
        "Name": "Public Opinion Quarterly",
        "Broad Field": "Political Science",
        "URL": "https://academic.oup.com/poq",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Focuses on the field of public opinion research."
    },
    {
        "Name": "International Organization",
        "Broad Field": "Political Science",
        "URL": "https://www.cambridge.org/core/journals/international-organization",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Addresses international relations and global governance issues."
    },
    # Economics
    {
        "Name": "American Economic Review",
        "Broad Field": "Economics",
        "URL": "https://www.aeaweb.org/journals/aer",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Publishes research across all areas of economics."
    },
    {
        "Name": "Quarterly Journal of Economics",
        "Broad Field": "Economics",
        "URL": "https://academic.oup.com/qje",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Features significant research on economic theory and practice."
    },
    {
        "Name": "Journal of Political Economy",
        "Broad Field": "Economics",
        "URL": "https://www.jstor.org/journal/jpolieco",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Covers all areas of economic theory and policy."
    },
    {
        "Name": "Econometrica",
        "Broad Field": "Economics",
        "URL": "https://www.econometricsociety.org/publications/econometrica",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Features research on econometrics and statistical methods in economics."
    },
    {
        "Name": "Review of Economic Studies",
        "Broad Field": "Economics",
        "URL": "https://academic.oup.com/restud",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Publishes innovative research in economic theory and practice."
    },
    # Psychology
    {
        "Name": "Psychological Review",
        "Broad Field": "Psychology",
        "URL": "https://www.apa.org/pubs/journals/rev",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Focuses on theoretical contributions to psychology."
    },
    {
        "Name": "Journal of Personality and Social Psychology",
        "Broad Field": "Psychology",
        "URL": "https://www.apa.org/pubs/journals/psp",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Covers research in personality and social psychology."
    },
    {
        "Name": "Developmental Psychology",
        "Broad Field": "Psychology",
        "URL": "https://www.apa.org/pubs/journals/dev",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Focuses on developmental psychology research."
    },
    {
        "Name": "Social Psychological and Personality Science",
        "Broad Field": "Psychology",
        "URL": "https://journals.sagepub.com/home/spq",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Explores social psychology and personality research."
    },
    {
        "Name": "Health Psychology",
        "Broad Field": "Psychology",
        "URL": "https://psycnet.apa.org/journal/hea",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Examines psychological aspects of health and illness."
    },
    # Anthropology
    {
        "Name": "American Anthropologist",
        "Broad Field": "Anthropology",
        "URL": "https://anthrosource.onlinelibrary.wiley.com/journal/15481433",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Covers research across all areas of anthropology."
    },
    {
        "Name": "Current Anthropology",
        "Broad Field": "Anthropology",
        "URL": "https://www.jstor.org/journal/curanth",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Features current research and theoretical discussions in anthropology."
    },
    {
        "Name": "Journal of Anthropological Research",
        "Broad Field": "Anthropology",
        "URL": "https://www.jstor.org/journal/janthresearch",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Publishes anthropological research from diverse subfields."
    },
    {
        "Name": "Cultural Anthropology",
        "Broad Field": "Anthropology",
        "URL": "https://onlinelibrary.wiley.com/journal/15481474",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Focuses on contemporary cultural anthropology research."
    },
    {
        "Name": "Ethnology",
        "Broad Field": "Anthropology",
        "URL": "https://www.jstor.org/journal/ethnology",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Explores ethnographic and theoretical research in anthropology."
    },
    # Education
    {
        "Name": "Review of Educational Research",
        "Broad Field": "Education",
        "URL": "https://journals.sagepub.com/home/rer",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Reviews significant developments in educational research."
    },
    {
        "Name": "Educational Evaluation and Policy Analysis",
        "Broad Field": "Education",
        "URL": "https://journals.sagepub.com/home/eepa",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Focuses on educational policy and evaluation research."
    },
    {
        "Name": "Journal of Educational Psychology",
        "Broad Field": "Education",
        "URL": "https://www.apa.org/pubs/journals/edu",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Covers research in educational psychology."
    },
    {
        "Name": "American Educational Research Journal",
        "Broad Field": "Education",
        "URL": "https://journals.sagepub.com/home/aer",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Publishes research on educational theory and practice."
    },
    {
        "Name": "Teaching and Teacher Education",
        "Broad Field": "Education",
        "URL": "https://www.jstor.org/journal/teacheduc",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Focuses on teacher education and pedagogical research."
    },
    # Human Geography
    {
        "Name": "Progress in Human Geography",
        "Broad Field": "Geography",
        "URL": "https://journals.sagepub.com/home/phg",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Publishes critical reviews and advancements in human geography."
    },
    {
        "Name": "Annals of the Association of American Geographers",
        "Broad Field": "Geography",
        "URL": "https://www.tandfonline.com/toc/rtag20/current",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Covers a wide range of geographical research."
    },
    {
        "Name": "Social & Cultural Geography",
        "Broad Field": "Geography",
        "URL": "https://www.tandfonline.com/toc/rcg20/current",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Focuses on the social and cultural aspects of geography."
    },
    {
        "Name": "Transactions of the Institute of British Geographers",
        "Broad Field": "Geography",
        "URL": "https://onlinelibrary.wiley.com/journal/14752749",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Explores geographical research and methods."
    },
    {
        "Name": "Urban Studies",
        "Broad Field": "Geography",
        "URL": "https://journals.sagepub.com/home/usj",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Focuses on urban research and issues."
    },
    # Communication
    {
        "Name": "Journal of Communication",
        "Broad Field": "Communication",
        "URL": "https://academic.oup.com/joc",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Covers research across all areas of communication."
    },
    {
        "Name": "Communication Research",
        "Broad Field": "Communication",
        "URL": "https://academic.oup.com/cr",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Features research on communication processes and effects."
    },
    {
        "Name": "Human Communication Research",
        "Broad Field": "Communication",
        "URL": "https://onlinelibrary.wiley.com/journal/14682858",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Explores human communication and its implications."
    },
    {
        "Name": "Media Psychology",
        "Broad Field": "Communication",
        "URL": "https://www.tandfonline.com/toc/hmps20/current",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Focuses on the psychological aspects of media and communication."
    },
    {
        "Name": "International Journal of Communication",
        "Broad Field": "Communication",
        "URL": "https://ijoc.org/index.php/ijoc",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Covers research in all areas of communication and media studies."
    },
    # Public Health
    {
        "Name": "American Journal of Public Health",
        "Broad Field": "Public Health",
        "URL": "https://ajph.aphapublications.org/",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Focuses on public health research and policy."
    },
    {
        "Name": "Public Health Reports",
        "Broad Field": "Public Health",
        "URL": "https://journals.sagepub.com/home/phr",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Publishes research and reviews on public health issues."
    },
    {
        "Name": "Social Science & Medicine",
        "Broad Field": "Public Health",
        "URL": "https://www.journals.elsevier.com/social-science-and-medicine",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Explores the intersections of social science and health."
    },
    {
        "Name": "Health Affairs",
        "Broad Field": "Public Health",
        "URL": "https://www.healthaffairs.org/",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Focuses on health policy and research."
    },
    {
        "Name": "Journal of Public Health",
        "Broad Field": "Public Health",
        "URL": "https://academic.oup.com/jph",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Publishes research on public health practice and policy."
    },
    # Additional Journals
    {
        "Name": "Journal of Social Issues",
        "Broad Field": "General Social Science",
        "URL": "https://onlinelibrary.wiley.com/journal/15404560",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Addresses a range of social issues from multiple perspectives."
    },
    {
        "Name": "Social Science Quarterly",
        "Broad Field": "General Social Science",
        "URL": "https://www.jstor.org/journal/socsciquart",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Publishes research on a variety of social science topics."
    },
    {
        "Name": "Theory and Society",
        "Broad Field": "Sociology",
        "URL": "https://link.springer.com/journal/11186",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Focuses on theoretical research in sociology."
    },
    {
        "Name": "American Sociological Review",
        "Broad Field": "Sociology",
        "URL": "https://journals.sagepub.com/home/asr",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Publishes research on sociological theory and empirical research."
    },
    {
        "Name": "Journal of Conflict Resolution",
        "Broad Field": "Political Science",
        "URL": "https://journals.sagepub.com/home/jcr",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Focuses on research related to conflict resolution and management."
    },
    {
        "Name": "Political Analysis",
        "Broad Field": "Political Science",
        "URL": "https://academic.oup.com/pan",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Covers methods and techniques in political science research."
    },
    {
        "Name": "Journal of Economic Literature",
        "Broad Field": "Economics",
        "URL": "https://www.aeaweb.org/journals/jel",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Provides reviews and summaries of economic research."
    },
    {
        "Name": "Journal of Economic Perspectives",
        "Broad Field": "Economics",
        "URL": "https://www.aeaweb.org/journals/jep",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Offers articles on economic theory and policy issues."
    },
    {
        "Name": "Journal of Experimental Psychology: General",
        "Broad Field": "Psychology",
        "URL": "https://www.apa.org/pubs/journals/xge",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Covers research in experimental psychology."
    },
    {
        "Name": "Journal of Applied Psychology",
        "Broad Field": "Psychology",
        "URL": "https://www.apa.org/pubs/journals/apl",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Focuses on research related to applied psychology."
    },
    {
        "Name": "American Ethnologist",
        "Broad Field": "Anthropology",
        "URL": "https://anthrosource.onlinelibrary.wiley.com/journal/15481484",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Publishes research in cultural and social anthropology."
    },
    {
        "Name": "Journal of the Royal Anthropological Institute",
        "Broad Field": "Anthropology",
        "URL": "https://onlinelibrary.wiley.com/journal/14679853",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Focuses on anthropological research and theory."
    },
    {
        "Name": "Journal of Research in Science Teaching",
        "Broad Field": "Education",
        "URL": "https://onlinelibrary.wiley.com/journal/10982736",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Covers research in science education."
    },
    {
        "Name": "Review of Educational Research",
        "Broad Field": "Education",
        "URL": "https://journals.sagepub.com/home/rer",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Provides comprehensive reviews of educational research."
    },
    {
        "Name": "Geoforum",
        "Broad Field": "Geography",
        "URL": "https://www.jstor.org/journal/geoforum",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Focuses on geographical research and discussions."
    },
    {
        "Name": "The Professional Geographer",
        "Broad Field": "Geography",
        "URL": "https://www.tandfonline.com/toc/uptg20/current",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Explores professional and applied geography research."
    },
    {
        "Name": "Journal of Broadcasting & Electronic Media",
        "Broad Field": "Communication",
        "URL": "https://www.tandfonline.com/toc/hbem20/current",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Covers research in broadcasting and electronic media."
    },
    {
        "Name": "Communication Theory",
        "Broad Field": "Communication",
        "URL": "https://onlinelibrary.wiley.com/journal/14682885",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Focuses on theoretical advancements in communication research."
    },
    {
        "Name": "Preventive Medicine",
        "Broad Field": "Public Health",
        "URL": "https://www.journals.elsevier.com/preventive-medicine",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Focuses on preventive health research and interventions."
    },
    {
        "Name": "Journal of Epidemiology and Community Health",
        "Broad Field": "Public Health",
        "URL": "https://jech.bmj.com/",
        "Cite Score": "",
        "Impact Factor": "",
        "Description": "Publishes research on epidemiology and community health."
    },
    {
        "Name": "Nature",
        "Broad Field": "Multidisciplinary",
        "URL": "https://www.nature.com/nature",
        "Cite Score": "69.8",
        "Impact Factor": "42.54",
        "Description": "The world's leading multidisciplinary science journal."
    },
    {
        "Name": "Nature Communications",
        "Broad Field": "Multidisciplinary",
        "URL": "https://www.nature.com/ncomms",
        "Cite Score": "15.0",
        "Impact Factor": "14.91",
        "Description": "An open-access journal that publishes high-quality research across all areas of the natural sciences."
    },
    {
        "Name": "Nature Medicine",
        "Broad Field": "Medicine",
        "URL": "https://www.nature.com/nm",
        "Cite Score": "27.6",
        "Impact Factor": "53.44",
        "Description": "Focuses on the latest research in all areas of clinical and translational medicine."
    },
    {
        "Name": "Nature Biotechnology",
        "Broad Field": "Biotechnology",
        "URL": "https://www.nature.com/nbt",
        "Cite Score": "20.1",
        "Impact Factor": "58.08",
        "Description": "Publishes research in all aspects of biotechnology."
    },
    {
        "Name": "Nature Physics",
        "Broad Field": "Physics",
        "URL": "https://www.nature.com/nphys",
        "Cite Score": "20.1",
        "Impact Factor": "21.63",
        "Description": "Features research in all areas of physics, including theoretical and experimental studies."
    },
    {
        "Name": "Nature Chemistry",
        "Broad Field": "Chemistry",
        "URL": "https://www.nature.com/nchem",
        "Cite Score": "17.4",
        "Impact Factor": "26.12",
        "Description": "Publishes research in all areas of chemistry."
    },
    {
        "Name": "Nature Materials",
        "Broad Field": "Materials Science",
        "URL": "https://www.nature.com/nmat",
        "Cite Score": "17.4",
        "Impact Factor": "39.30",
        "Description": "Focuses on research in materials science, including experimental and theoretical studies."
    },
    {
        "Name": "Nature Reviews Molecular Cell Biology",
        "Broad Field": "Cell Biology",
        "URL": "https://www.nature.com/nrm",
        "Cite Score": "35.2",
        "Impact Factor": "50.16",
        "Description": "Provides reviews of the latest research in molecular and cell biology."
    },
    {
        "Name": "Nature Structural & Molecular Biology",
        "Broad Field": "Structural Biology",
        "URL": "https://www.nature.com/nsmb",
        "Cite Score": "12.8",
        "Impact Factor": "11.73",
        "Description": "Covers research on the structure and function of biological macromolecules."
    },
    {
        "Name": "Nature Reviews Drug Discovery",
        "Broad Field": "Pharmacology",
        "URL": "https://www.nature.com/nrd",
        "Cite Score": "23.7",
        "Impact Factor": "52.45",
        "Description": "Reviews the latest developments in drug discovery and development."
    }, 
    {
    "Name": "Nature",
    "Broad Field": "Multidisciplinary",
    "URL": "https://www.nature.com/nature",
    "Cite Score": "69.8",
    "Impact Factor": "42.54",
    "Description": "The world's leading multidisciplinary science journal."
},
{
    "Name": "Nature Communications",
    "Broad Field": "Multidisciplinary",
    "URL": "https://www.nature.com/ncomms",
    "Cite Score": "15.0",
    "Impact Factor": "14.91",
    "Description": "An open-access journal that publishes high-quality research across all areas of the natural sciences."
},
{
    "Name": "Nature Medicine",
    "Broad Field": "Medicine",
    "URL": "https://www.nature.com/nm",
    "Cite Score": "27.6",
    "Impact Factor": "53.44",
    "Description": "Focuses on the latest research in all areas of clinical and translational medicine."
},
{
    "Name": "Nature Biotechnology",
    "Broad Field": "Biotechnology",
    "URL": "https://www.nature.com/nbt",
    "Cite Score": "20.1",
    "Impact Factor": "58.08",
    "Description": "Publishes research in all aspects of biotechnology."
},
{
    "Name": "Nature Physics",
    "Broad Field": "Physics",
    "URL": "https://www.nature.com/nphys",
    "Cite Score": "20.1",
    "Impact Factor": "21.63",
    "Description": "Features research in all areas of physics, including theoretical and experimental studies."
},
{
    "Name": "Nature Chemistry",
    "Broad Field": "Chemistry",
    "URL": "https://www.nature.com/nchem",
    "Cite Score": "17.4",
    "Impact Factor": "26.12",
    "Description": "Publishes research in all areas of chemistry."
},
{
    "Name": "Nature Materials",
    "Broad Field": "Materials Science",
    "URL": "https://www.nature.com/nmat",
    "Cite Score": "17.4",
    "Impact Factor": "39.30",
    "Description": "Focuses on research in materials science, including experimental and theoretical studies."
},
{
    "Name": "Nature Reviews Molecular Cell Biology",
    "Broad Field": "Cell Biology",
    "URL": "https://www.nature.com/nrm",
    "Cite Score": "35.2",
    "Impact Factor": "50.16",
    "Description": "Provides reviews of the latest research in molecular and cell biology."
},
{
    "Name": "Nature Structural & Molecular Biology",
    "Broad Field": "Structural Biology",
    "URL": "https://www.nature.com/nsmb",
    "Cite Score": "12.8",
    "Impact Factor": "11.73",
    "Description": "Covers research on the structure and function of biological macromolecules."
},
{
    "Name": "Nature Reviews Drug Discovery",
    "Broad Field": "Pharmacology",
    "URL": "https://www.nature.com/nrd",
    "Cite Score": "23.7",
    "Impact Factor": "52.45",
    "Description": "Reviews the latest developments in drug discovery and development."
},
{
    "Name": "Nature Reviews Genetics",
    "Broad Field": "Genetics",
    "URL": "https://www.nature.com/nrg",
    "Cite Score": "38.4",
    "Impact Factor": "49.55",
    "Description": "Covers reviews in genetics and genomics, focusing on major advances and controversies."
},
{
    "Name": "Nature Reviews Immunology",
    "Broad Field": "Immunology",
    "URL": "https://www.nature.com/nri",
    "Cite Score": "35.2",
    "Impact Factor": "49.62",
    "Description": "Provides reviews on the latest research in immunology."
},
{
    "Name": "Nature Reviews Microbiology",
    "Broad Field": "Microbiology",
    "URL": "https://www.nature.com/nrmicro",
    "Cite Score": "30.6",
    "Impact Factor": "47.09",
    "Description": "Reviews significant research in microbiology and microbial pathogenesis."
},
{
    "Name": "Nature Reviews Neuroscience",
    "Broad Field": "Neuroscience",
    "URL": "https://www.nature.com/nrn",
    "Cite Score": "39.2",
    "Impact Factor": "41.47",
    "Description": "Focuses on comprehensive reviews of the latest research in neuroscience."
},
{
    "Name": "Nature Reviews Physics",
    "Broad Field": "Physics",
    "URL": "https://www.nature.com/nrphys",
    "Cite Score": "32.0",
    "Impact Factor": "50.80",
    "Description": "Covers reviews of significant developments in physics."
},
{
    "Name": "Nature Reviews Clinical Oncology",
    "Broad Field": "Oncology",
    "URL": "https://www.nature.com/nrclinonc",
    "Cite Score": "29.5",
    "Impact Factor": "37.36",
    "Description": "Provides reviews on clinical oncology and cancer treatment."
},
{
    "Name": "Nature Reviews Cardiology",
    "Broad Field": "Cardiology",
    "URL": "https://www.nature.com/nrcardio",
    "Cite Score": "25.6",
    "Impact Factor": "37.20",
    "Description": "Focuses on reviews of advances and research in cardiology."
},
{
    "Name": "Nature Reviews Endocrinology",
    "Broad Field": "Endocrinology",
    "URL": "https://www.nature.com/nrendo",
    "Cite Score": "28.4",
    "Impact Factor": "37.19",
    "Description": "Reviews research in endocrinology and related areas."
},
{
    "Name": "Nature Reviews Nephrology",
    "Broad Field": "Nephrology",
    "URL": "https://www.nature.com/nrneph",
    "Cite Score": "23.6",
    "Impact Factor": "26.73",
    "Description": "Provides insights into recent research in nephrology."
},
{
    "Name": "Nature Reviews Rheumatology",
    "Broad Field": "Rheumatology",
    "URL": "https://www.nature.com/nrrheum",
    "Cite Score": "21.7",
    "Impact Factor": "28.81",
    "Description": "Covers advances in rheumatology and related diseases."
},
{
    "Name": "Cell",
    "Broad Field": "Cell Biology",
    "URL": "https://www.cell.com/cell",
    "Cite Score": "30.1",
    "Impact Factor": "38.63",
    "Description": "Covers the latest research in cell biology and molecular biology."
},
{
    "Name": "Science",
    "Broad Field": "Multidisciplinary",
    "URL": "https://www.sciencemag.org",
    "Cite Score": "37.0",
    "Impact Factor": "41.84",
    "Description": "A leading journal covering all fields of science, including physics, biology, and chemistry."
},
{
    "Name": "The Lancet",
    "Broad Field": "Medicine",
    "URL": "https://www.thelancet.com",
    "Cite Score": "48.0",
    "Impact Factor": "59.39",
    "Description": "Publishes cutting-edge research in clinical medicine and public health."
},
{
    "Name": "Journal of the American Medical Association (JAMA)",
    "Broad Field": "Medicine",
    "URL": "https://jamanetwork.com/journals/jama",
    "Cite Score": "25.4",
    "Impact Factor": "56.27",
    "Description": "Covers a wide range of medical and health-related topics."
},
{
    "Name": "New England Journal of Medicine (NEJM)",
    "Broad Field": "Medicine",
    "URL": "https://www.nejm.org",
    "Cite Score": "42.0",
    "Impact Factor": "91.25",
    "Description": "Publishes high-impact research in clinical medicine and related disciplines."
},
{
    "Name": "Nature Reviews Cancer",
    "Broad Field": "Oncology",
    "URL": "https://www.nature.com/nrc",
    "Cite Score": "31.2",
    "Impact Factor": "59.24",
    "Description": "Provides reviews of research in cancer biology and treatment."
},
{
    "Name": "Nature Reviews Drug Discovery",
    "Broad Field": "Pharmacology",
    "URL": "https://www.nature.com/nrd",
    "Cite Score": "23.7",
    "Impact Factor": "52.45",
    "Description": "Reviews the latest developments in drug discovery and development."
},
{
    "Name": "Nature Reviews Molecular Cell Biology",
    "Broad Field": "Cell Biology",
    "URL": "https://www.nature.com/nrm",
    "Cite Score": "35.2",
    "Impact Factor": "50.16",
    "Description": "Provides reviews of the latest research in molecular and cell biology."
},
{
    "Name": "Nature Reviews Genetics",
    "Broad Field": "Genetics",
    "URL": "https://www.nature.com/nrg",
    "Cite Score": "38.4",
    "Impact Factor": "49.55",
    "Description": "Covers reviews in genetics and genomics, focusing on major advances and controversies."
},
{
    "Name": "Nature Reviews Immunology",
    "Broad Field": "Immunology",
    "URL": "https://www.nature.com/nri",
    "Cite Score": "35.2",
    "Impact Factor": "49.62",
    "Description": "Provides reviews on the latest research in immunology."
},
{
    "Name": "Nature Reviews Microbiology",
    "Broad Field": "Microbiology",
    "URL": "https://www.nature.com/nrmicro",
    "Cite Score": "30.6",
    "Impact Factor": "47.09",
    "Description": "Reviews significant research in microbiology and microbial pathogenesis."
},
{
    "Name": "Nature Reviews Neuroscience",
    "Broad Field": "Neuroscience",
    "URL": "https://www.nature.com/nrn",
    "Cite Score": "39.2",
    "Impact Factor": "41.47",
    "Description": "Focuses on comprehensive reviews of the latest research in neuroscience."
},
{
    "Name": "Nature Reviews Physics",
    "Broad Field": "Physics",
    "URL": "https://www.nature.com/nrphys",
    "Cite Score": "32.0",
    "Impact Factor": "50.80",
    "Description": "Covers reviews of significant developments in physics."
},
{
    "Name": "Nature Reviews Clinical Oncology",
    "Broad Field": "Oncology",
    "URL": "https://www.nature.com/nrclinonc",
    "Cite Score": "29.5",
    "Impact Factor": "37.36",
    "Description": "Provides reviews on clinical oncology and cancer treatment."
},
{
    "Name": "Nature Reviews Cardiology",
    "Broad Field": "Cardiology",
    "URL": "https://www.nature.com/nrcardio",
    "Cite Score": "25.6",
    "Impact Factor": "37.20",
    "Description": "Focuses on reviews of advances and research in cardiology."
},
{
    "Name": "Nature Reviews Endocrinology",
    "Broad Field": "Endocrinology",
    "URL": "https://www.nature.com/nrendo",
    "Cite Score": "28.4",
    "Impact Factor": "37.19",
    "Description": "Reviews research in endocrinology and related areas."
},
{
    "Name": "Nature Reviews Nephrology",
    "Broad Field": "Nephrology",
    "URL": "https://www.nature.com/nrneph",
    "Cite Score": "23.6",
    "Impact Factor": "26.73",
    "Description": "Provides insights into recent research in nephrology."
},
{
    "Name": "Nature Reviews Rheumatology",
    "Broad Field": "Rheumatology",
    "URL": "https://www.nature.com/nrrheum",
    "Cite Score": "21.7",
    "Impact Factor": "28.81",
    "Description": "Covers advances in rheumatology and related diseases."
}
]

# %% [markdown]
# Use format below to update above table. Use following prompt to search journals using ChatGPT:
#
# List all elsivier journals in the format below. Exclude [] in the code.
# {
#         "Name": "Name Here",
#         "Broad Field": "Link Here",
#         "URL": "Assigned Category",
#         "Cite Score": " ",
#         "Impact Factor": " ",
#         "Description": "Describe in Few Words"
#     }

# %%
# Filepath to save the CSV
csv_file_path = "list of journals.csv"

# Call the function with any number of database lists
update_csv_file(csv_file_path, jdb0829241600)

print(f"CSV file '{csv_file_path}' has been updated.")

# Read the CSV file into a DataFrame
df = pd.read_csv(csv_file_path)

# Get the dimensions of the DataFrame
num_rows, num_columns = df.shape

print(f"The CSV file has {num_rows} rows and {num_columns} columns.")
# Out:
# CSV file 'list of journals.csv' has been updated.
# The CSV file has 95 rows and 7 columns.
